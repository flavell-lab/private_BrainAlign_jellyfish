# %% [markdown]
# ### training the BrainAlignNet

# %%
import os
os.chdir("../scripts")

# %%
from train import set_GPU, fit_deepreg
# import train
# Out:
# 2025-02-11 23:37:37.628467: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 23:37:37.628511: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 23:37:37.630071: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
base = "/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet"
config_path = f"{base}/demo_notebook/dots_pad_config.yaml"
log_dir = f"{base}/demo_notebook"
experiment_name = "demo_dots_mask"
max_epochs = 1500
initial_epoch = 0

# %%
# %env DEEPREG_LOG_LEVEL=0
# import tensorflow as tf
# tf.debugging.enable_check_numerics()
# tf.config.experimental_run_functions_eagerly(True)
set_GPU(2)
fit_deepreg(
    config_path,
    log_dir,
    experiment_name,
    max_epochs,
    initial_epoch)
# Out:
# env: DEEPREG_LOG_LEVEL=0
# Built inputs.
# Built control points.
# Concatenated images.
# {'extract_levels': ListWrapper([0, 1, 2, 3]), 'name': 'local', 'num_channel_initial': 16}
# Built backbone.
# Built DDF.
# Built warping.
# Built outputs.
# 2025-02-11 23:37:42 | WARNING  | The configuration for loss regularization is not defined. Therefore it is not used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739317108.415079 1233914 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1/1500
# 1/1 [==============================] - 6s 6s/step - loss: 9.5347 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0433 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7807 - loss/label_CentroidDistance_weighted: 10.5781 - metric/ddf_mean: -0.0051 - metric/ddf_min: -0.6045 - metric/ddf_max: 0.0024 - val_loss: 9.5375 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0402 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7769 - val_loss/label_CentroidDistance_weighted: 10.5777 - val_metric/ddf_mean: -6.6909e-05 - val_metric/ddf_min: -5.5669e-04 - val_metric/ddf_max: 2.2143e-04
# Epoch 2/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.5331 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0105 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0452 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7822 - loss/label_CentroidDistance_weighted: 10.5782 - metric/ddf_mean: -0.0097 - metric/ddf_min: -0.9070 - metric/ddf_max: 0.0046 - val_loss: 9.5374 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0402 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7767 - val_loss/label_CentroidDistance_weighted: 10.5777 - val_metric/ddf_mean: -1.2097e-04 - val_metric/ddf_min: -8.7271e-04 - val_metric/ddf_max: 3.9313e-04
# Epoch 3/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.5312 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0105 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0469 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7814 - loss/label_CentroidDistance_weighted: 10.5781 - metric/ddf_mean: -0.0126 - metric/ddf_min: -1.0264 - metric/ddf_max: 0.0081 - val_loss: 9.5374 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0402 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7763 - val_loss/label_CentroidDistance_weighted: 10.5776 - val_metric/ddf_mean: -1.6976e-04 - val_metric/ddf_min: -0.0012 - val_metric/ddf_max: 6.4000e-04
# Epoch 4/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.5286 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0105 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0492 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7775 - loss/label_CentroidDistance_weighted: 10.5778 - metric/ddf_mean: -0.0144 - metric/ddf_min: -1.3340 - metric/ddf_max: 0.0129 - val_loss: 9.5374 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0402 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7759 - val_loss/label_CentroidDistance_weighted: 10.5776 - val_metric/ddf_mean: -2.1575e-04 - val_metric/ddf_min: -0.0017 - val_metric/ddf_max: 9.6577e-04
# Epoch 5/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.5255 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0105 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0518 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7729 - loss/label_CentroidDistance_weighted: 10.5773 - metric/ddf_mean: -0.0159 - metric/ddf_min: -1.6168 - metric/ddf_max: 0.0186 - val_loss: 9.5373 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0402 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7754 - val_loss/label_CentroidDistance_weighted: 10.5775 - val_metric/ddf_mean: -2.6285e-04 - val_metric/ddf_min: -0.0022 - val_metric/ddf_max: 0.0014
# Epoch 6/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.5221 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0105 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0547 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7671 - loss/label_CentroidDistance_weighted: 10.5767 - metric/ddf_mean: -0.0171 - metric/ddf_min: -1.8034 - metric/ddf_max: 0.0251 - val_loss: 9.5372 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0402 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7747 - val_loss/label_CentroidDistance_weighted: 10.5775 - val_metric/ddf_mean: -3.1614e-04 - val_metric/ddf_min: -0.0029 - val_metric/ddf_max: 0.0019
# Epoch 7/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.5184 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0577 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7604 - loss/label_CentroidDistance_weighted: 10.5760 - metric/ddf_mean: -0.0186 - metric/ddf_min: -2.0335 - metric/ddf_max: 0.0631 - val_loss: 9.5371 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0402 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7739 - val_loss/label_CentroidDistance_weighted: 10.5774 - val_metric/ddf_mean: -3.6348e-04 - val_metric/ddf_min: -0.0036 - val_metric/ddf_max: 0.0025
# Epoch 8/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.5127 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0626 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7536 - loss/label_CentroidDistance_weighted: 10.5754 - metric/ddf_mean: -0.0194 - metric/ddf_min: -2.3220 - metric/ddf_max: 0.2754 - val_loss: 9.5371 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7731 - val_loss/label_CentroidDistance_weighted: 10.5773 - val_metric/ddf_mean: -3.8258e-04 - val_metric/ddf_min: -0.0043 - val_metric/ddf_max: 0.0031
# Epoch 9/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.5053 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0107 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0693 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7468 - loss/label_CentroidDistance_weighted: 10.5747 - metric/ddf_mean: -0.0195 - metric/ddf_min: -2.6376 - metric/ddf_max: 0.5657 - val_loss: 9.5370 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7721 - val_loss/label_CentroidDistance_weighted: 10.5772 - val_metric/ddf_mean: -3.8707e-04 - val_metric/ddf_min: -0.0051 - val_metric/ddf_max: 0.0039
# Epoch 10/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.4972 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0108 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0768 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7399 - loss/label_CentroidDistance_weighted: 10.5740 - metric/ddf_mean: -0.0194 - metric/ddf_min: -3.0342 - metric/ddf_max: 0.9221 - val_loss: 9.5368 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7711 - val_loss/label_CentroidDistance_weighted: 10.5771 - val_metric/ddf_mean: -3.8250e-04 - val_metric/ddf_min: -0.0060 - val_metric/ddf_max: 0.0048
# Epoch 11/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.4882 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0109 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0851 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7327 - loss/label_CentroidDistance_weighted: 10.5733 - metric/ddf_mean: -0.0192 - metric/ddf_min: -3.4154 - metric/ddf_max: 1.2791 - val_loss: 9.5367 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7699 - val_loss/label_CentroidDistance_weighted: 10.5770 - val_metric/ddf_mean: -3.7252e-04 - val_metric/ddf_min: -0.0069 - val_metric/ddf_max: 0.0058
# Epoch 12/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.4781 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0109 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0944 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7249 - loss/label_CentroidDistance_weighted: 10.5725 - metric/ddf_mean: -0.0196 - metric/ddf_min: -3.7223 - metric/ddf_max: 1.5579 - val_loss: 9.5366 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7685 - val_loss/label_CentroidDistance_weighted: 10.5769 - val_metric/ddf_mean: -3.5986e-04 - val_metric/ddf_min: -0.0080 - val_metric/ddf_max: 0.0069
# Epoch 13/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.4674 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0110 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.1044 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7176 - loss/label_CentroidDistance_weighted: 10.5718 - metric/ddf_mean: -0.0198 - metric/ddf_min: -3.8478 - metric/ddf_max: 1.8119 - val_loss: 9.5364 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7671 - val_loss/label_CentroidDistance_weighted: 10.5767 - val_metric/ddf_mean: -3.4228e-04 - val_metric/ddf_min: -0.0091 - val_metric/ddf_max: 0.0081
# Epoch 14/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.4548 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0112 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.1163 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7109 - loss/label_CentroidDistance_weighted: 10.5711 - metric/ddf_mean: -0.0193 - metric/ddf_min: -4.6215 - metric/ddf_max: 2.3430 - val_loss: 9.5363 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7655 - val_loss/label_CentroidDistance_weighted: 10.5765 - val_metric/ddf_mean: -3.1639e-04 - val_metric/ddf_min: -0.0103 - val_metric/ddf_max: 0.0095
# Epoch 15/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.4399 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0113 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.1305 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.7041 - loss/label_CentroidDistance_weighted: 10.5704 - metric/ddf_mean: -0.0185 - metric/ddf_min: -5.7100 - metric/ddf_max: 3.0654 - val_loss: 9.5361 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7638 - val_loss/label_CentroidDistance_weighted: 10.5764 - val_metric/ddf_mean: -2.8246e-04 - val_metric/ddf_min: -0.0116 - val_metric/ddf_max: 0.0109
# Epoch 16/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.4241 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0115 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.1458 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6994 - loss/label_CentroidDistance_weighted: 10.5699 - metric/ddf_mean: -0.0175 - metric/ddf_min: -6.6509 - metric/ddf_max: 3.7390 - val_loss: 9.5359 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7620 - val_loss/label_CentroidDistance_weighted: 10.5762 - val_metric/ddf_mean: -2.4264e-04 - val_metric/ddf_min: -0.0130 - val_metric/ddf_max: 0.0124
# Epoch 17/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.4074 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0116 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.1618 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6919 - loss/label_CentroidDistance_weighted: 10.5692 - metric/ddf_mean: -0.0173 - metric/ddf_min: -5.9377 - metric/ddf_max: 3.4300 - val_loss: 9.5357 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7601 - val_loss/label_CentroidDistance_weighted: 10.5760 - val_metric/ddf_mean: -2.0136e-04 - val_metric/ddf_min: -0.0144 - val_metric/ddf_max: 0.0140
# Epoch 18/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.3928 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0118 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.1761 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6888 - loss/label_CentroidDistance_weighted: 10.5689 - metric/ddf_mean: -0.0168 - metric/ddf_min: -6.9595 - metric/ddf_max: 4.2089 - val_loss: 9.5355 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7580 - val_loss/label_CentroidDistance_weighted: 10.5758 - val_metric/ddf_mean: -1.5701e-04 - val_metric/ddf_min: -0.0160 - val_metric/ddf_max: 0.0158
# Epoch 19/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.3716 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0120 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.1964 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6800 - loss/label_CentroidDistance_weighted: 10.5680 - metric/ddf_mean: -0.0155 - metric/ddf_min: -7.3951 - metric/ddf_max: 4.6259 - val_loss: 9.5352 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0403 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7558 - val_loss/label_CentroidDistance_weighted: 10.5756 - val_metric/ddf_mean: -1.0961e-04 - val_metric/ddf_min: -0.0177 - val_metric/ddf_max: 0.0176
# Epoch 20/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.3513 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0122 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.2164 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6766 - loss/label_CentroidDistance_weighted: 10.5677 - metric/ddf_mean: -0.0138 - metric/ddf_min: -8.6452 - metric/ddf_max: 5.6145 - val_loss: 9.5350 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7536 - val_loss/label_CentroidDistance_weighted: 10.5754 - val_metric/ddf_mean: -5.4562e-05 - val_metric/ddf_min: -0.0194 - val_metric/ddf_max: 0.0195
# Epoch 21/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.3319 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0124 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.2351 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6699 - loss/label_CentroidDistance_weighted: 10.5670 - metric/ddf_mean: -0.0128 - metric/ddf_min: -9.6777 - metric/ddf_max: 6.4779 - val_loss: 9.5348 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7514 - val_loss/label_CentroidDistance_weighted: 10.5751 - val_metric/ddf_mean: 4.1442e-06 - val_metric/ddf_min: -0.0211 - val_metric/ddf_max: 0.0214
# Epoch 22/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.3077 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0126 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.2581 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6578 - loss/label_CentroidDistance_weighted: 10.5658 - metric/ddf_mean: -0.0126 - metric/ddf_min: -9.4359 - metric/ddf_max: 6.3774 - val_loss: 9.5345 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7489 - val_loss/label_CentroidDistance_weighted: 10.5749 - val_metric/ddf_mean: 6.4134e-05 - val_metric/ddf_min: -0.0230 - val_metric/ddf_max: 0.0234
# Epoch 23/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.2877 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0128 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.2772 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6485 - loss/label_CentroidDistance_weighted: 10.5648 - metric/ddf_mean: -0.0120 - metric/ddf_min: -10.7179 - metric/ddf_max: 7.3970 - val_loss: 9.5342 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7464 - val_loss/label_CentroidDistance_weighted: 10.5746 - val_metric/ddf_mean: 1.2409e-04 - val_metric/ddf_min: -0.0249 - val_metric/ddf_max: 0.0256
# Epoch 24/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.2630 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0130 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.3017 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6464 - loss/label_CentroidDistance_weighted: 10.5646 - metric/ddf_mean: -0.0111 - metric/ddf_min: -10.8587 - metric/ddf_max: 7.6319 - val_loss: 9.5340 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7438 - val_loss/label_CentroidDistance_weighted: 10.5744 - val_metric/ddf_mean: 1.8823e-04 - val_metric/ddf_min: -0.0268 - val_metric/ddf_max: 0.0278
# Epoch 25/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.2441 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0132 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.3204 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6453 - loss/label_CentroidDistance_weighted: 10.5645 - metric/ddf_mean: -0.0101 - metric/ddf_min: -13.0896 - metric/ddf_max: 9.4965 - val_loss: 9.5337 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7411 - val_loss/label_CentroidDistance_weighted: 10.5741 - val_metric/ddf_mean: 2.5890e-04 - val_metric/ddf_min: -0.0289 - val_metric/ddf_max: 0.0300
# Epoch 26/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.2196 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0135 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.3456 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6518 - loss/label_CentroidDistance_weighted: 10.5652 - metric/ddf_mean: -0.0098 - metric/ddf_min: -13.0256 - metric/ddf_max: 9.5540 - val_loss: 9.5334 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7383 - val_loss/label_CentroidDistance_weighted: 10.5738 - val_metric/ddf_mean: 3.3600e-04 - val_metric/ddf_min: -0.0310 - val_metric/ddf_max: 0.0325
# Epoch 27/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.1997 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0137 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.3654 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6509 - loss/label_CentroidDistance_weighted: 10.5651 - metric/ddf_mean: -0.0094 - metric/ddf_min: -11.8002 - metric/ddf_max: 8.7003 - val_loss: 9.5331 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7353 - val_loss/label_CentroidDistance_weighted: 10.5735 - val_metric/ddf_mean: 4.1529e-04 - val_metric/ddf_min: -0.0332 - val_metric/ddf_max: 0.0350
# Epoch 28/1500
# 1/1 [==============================] - 4s 4s/step - loss: 9.1817 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0138 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.3807 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6230 - loss/label_CentroidDistance_weighted: 10.5623 - metric/ddf_mean: -0.0085 - metric/ddf_min: -12.8493 - metric/ddf_max: 9.6543 - val_loss: 9.5328 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0404 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7323 - val_loss/label_CentroidDistance_weighted: 10.5732 - val_metric/ddf_mean: 4.9940e-04 - val_metric/ddf_min: -0.0355 - val_metric/ddf_max: 0.0375
# Epoch 29/1500
# 1/1 [==============================] - 3s 3s/step - loss: 9.1546 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0141 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.4073 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 105.6182 - loss/label_CentroidDistance_weighted: 10.5618 - metric/ddf_mean: -0.0078 - metric/ddf_min: -14.4434 - metric/ddf_max: 11.0410 - val_loss: 9.5325 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0104 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0405 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.7292 - val_loss/label_CentroidDistance_weighted: 10.5729 - val_metric/ddf_mean: 5.9132e-04 - val_metric/ddf_min: -0.0378 - val_metric/ddf_max: 0.0402
# Epoch 30/1500
# ...
# Epoch 390/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.6977 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0358 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.5778 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.7557 - loss/label_CentroidDistance_weighted: 7.2756 - metric/ddf_mean: 0.3505 - metric/ddf_min: -102.6016 - metric/ddf_max: 171.5230 - val_loss: 9.5307 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0586 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8930 - val_loss/label_CentroidDistance_weighted: 10.5893 - val_metric/ddf_mean: 0.0030 - val_metric/ddf_min: -1.0675 - val_metric/ddf_max: 0.9541
# Epoch 391/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.6851 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0357 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.5686 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.5372 - loss/label_CentroidDistance_weighted: 7.2537 - metric/ddf_mean: 0.3474 - metric/ddf_min: -102.6533 - metric/ddf_max: 179.2318 - val_loss: 9.5302 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0588 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8903 - val_loss/label_CentroidDistance_weighted: 10.5890 - val_metric/ddf_mean: 0.0041 - val_metric/ddf_min: -1.0447 - val_metric/ddf_max: 0.9386
# Epoch 392/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.6236 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0361 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6055 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.2914 - loss/label_CentroidDistance_weighted: 7.2291 - metric/ddf_mean: 0.3445 - metric/ddf_min: -100.1905 - metric/ddf_max: 180.6955 - val_loss: 9.5297 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0592 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8890 - val_loss/label_CentroidDistance_weighted: 10.5889 - val_metric/ddf_mean: 0.0048 - val_metric/ddf_min: -1.0464 - val_metric/ddf_max: 0.9416
# Epoch 393/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.7038 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0362 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6154 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 73.1920 - loss/label_CentroidDistance_weighted: 7.3192 - metric/ddf_mean: 0.3481 - metric/ddf_min: -95.8745 - metric/ddf_max: 178.6711 - val_loss: 9.5293 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0594 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8877 - val_loss/label_CentroidDistance_weighted: 10.5888 - val_metric/ddf_mean: 0.0049 - val_metric/ddf_min: -1.0568 - val_metric/ddf_max: 0.9487
# Epoch 394/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.6352 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0362 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6222 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.5738 - loss/label_CentroidDistance_weighted: 7.2574 - metric/ddf_mean: 0.3452 - metric/ddf_min: -94.2074 - metric/ddf_max: 182.9222 - val_loss: 9.5289 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0599 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8882 - val_loss/label_CentroidDistance_weighted: 10.5888 - val_metric/ddf_mean: 0.0047 - val_metric/ddf_min: -1.1174 - val_metric/ddf_max: 0.9942
# Epoch 395/1500
# 1/1 [==============================] - 3s 3s/step - loss: 3.6085 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0363 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6300 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.3852 - loss/label_CentroidDistance_weighted: 7.2385 - metric/ddf_mean: 0.3475 - metric/ddf_min: -94.6501 - metric/ddf_max: 179.0157 - val_loss: 9.5287 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0601 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8879 - val_loss/label_CentroidDistance_weighted: 10.5888 - val_metric/ddf_mean: 0.0050 - val_metric/ddf_min: -1.1053 - val_metric/ddf_max: 0.9763
# Epoch 396/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.5838 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0364 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6432 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.2700 - loss/label_CentroidDistance_weighted: 7.2270 - metric/ddf_mean: 0.3457 - metric/ddf_min: -95.7102 - metric/ddf_max: 187.1133 - val_loss: 9.5284 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0607 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8908 - val_loss/label_CentroidDistance_weighted: 10.5891 - val_metric/ddf_mean: 0.0052 - val_metric/ddf_min: -1.2184 - val_metric/ddf_max: 1.0633
# Epoch 397/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.6487 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0365 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6488 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.9749 - loss/label_CentroidDistance_weighted: 7.2975 - metric/ddf_mean: 0.3583 - metric/ddf_min: -96.8456 - metric/ddf_max: 170.9545 - val_loss: 9.5284 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0608 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8918 - val_loss/label_CentroidDistance_weighted: 10.5892 - val_metric/ddf_mean: 0.0059 - val_metric/ddf_min: -1.1968 - val_metric/ddf_max: 1.0418
# Epoch 398/1500
# 1/1 [==============================] - 4s 4s/step - loss: 3.6080 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0366 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6604 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.6836 - loss/label_CentroidDistance_weighted: 7.2684 - metric/ddf_mean: 0.3604 - metric/ddf_min: -98.5981 - metric/ddf_max: 178.5416 - val_loss: 9.5285 - val_metric/moving_image_mean: 0.0015 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.0013 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.0106 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -1.0607 - val_metric/moving_label_mean: 257.0555 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 945.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 105.8923 - val_loss/label_CentroidDistance_weighted: 10.5892 - val_metric/ddf_mean: 0.0059 - val_metric/ddf_min: -1.1376 - val_metric/ddf_max: 0.9885
# Epoch 399/1500
# 1/1 [==============================] - ETA: 0s - loss: 3.5838 - metric/moving_image_mean: 0.0015 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.0013 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.0365 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -3.6548 - metric/moving_label_mean: 257.0555 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 945.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 72.3852 - loss/label_CentroidDistance_weighted: 7.2385 - metric/ddf_mean: 0.3592 - metric/ddf_min: -100.7984 - metric/ddf_max: 197.3476

# %% [markdown]
# ### register test (unseen) images with checkpoint (weights of the trained network)

# %%
from register import set_GPU, register
# Out:
# 2025-02-12 04:28:08.550389: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-12 04:28:08.587463: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-12 04:28:08.587494: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-12 04:28:08.589101: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-12 04:28:08.596186: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-12 04:28:09.268331: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model_config_path = config_path
# model_ckpt_path = f"/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet/demo_notebook/demo_data/save/ckpt-300"
model_ckpt_path = f"/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet/demo_notebook/demo_dots_mask/save/ckpt-1500"

# %%
set_GPU(3)
registered_outputs = register(model_config_path, model_ckpt_path)
# Out:
# /home/brian/data4/brian/PBnJ/test_data/circles_padded/fixed_images.h5
#   0%|          | 0/1 [00:00<?, ?it/s]2025-02-12 04:28:10.764477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46576 MB memory:  -> device: 3, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:c2:00.0, compute capability: 8.9
# 2025-02-12 04:28:11 | WARNING  | Log directory outputs/outputs exists already.
# 2025-02-12 04:28:11 | WARNING  | Using customized configuration. The code might break if the config doesn't match the saved model.
# Built inputs.
# Built control points.
# Concatenated images.
# {'extract_levels': ListWrapper([0, 1, 2, 3]), 'name': 'local', 'num_channel_initial': 16}
# Built backbone.
# Built DDF.
# Built warping.
# 2025-02-12 04:28:13 | WARNING  | The configuration for loss regularization is not defined. Therefore it is not used.
# 2025-02-12 04:28:13.844394: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 100%|██████████| 1/1 [00:15<00:00, 15.52s/it]
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.31
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.32
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.33
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.34
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.35
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.36
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.37
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.38
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.39
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.40
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.41
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.42
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.43
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.44
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.45
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.46
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.47
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.48
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.49
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.50
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.51
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.52
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.53
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.54
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.55
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.56
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.57
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.58
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.59
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.60
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.61
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.62
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.63
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.64
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.65
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.66
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.67
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.68
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.69
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.70
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.71
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.72
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.73
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.74
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.75
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.76
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.77
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.78
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.79
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.80
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.81
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.82
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.83
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.84
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.85
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.86
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.87
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.88
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.89
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.90
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.91
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.92
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.93
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.94
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.95
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.96
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.97
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.98
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.99
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.100
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.101
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.102
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.103
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.104
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.105
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.106
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.107
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.108
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.109
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.110
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.111
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.112
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.113
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.114
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.115
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.116
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.117
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.118
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.119
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.120
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.121
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.122
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.123
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.124
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.125
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.126
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.127
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.128
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.129
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.130
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.131
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.132
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.133
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.134
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.135
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.136
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.137
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.138
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.139
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.140
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.141
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.142
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.143
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.144
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.145
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.146
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.147
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.148

# %% [markdown]
# #### plot registered outputs

# %%
import matplotlib.pyplot as plt

# %%
experiment = 'circles_padded'
# experiment = 'stripes'
registered_outputs.keys()
# Out:
# dict_keys(['circles_padded'])

# %%
registration_prob = '1to2'
output_dict = registered_outputs[experiment][registration_prob]
warped_moving_image = output_dict['warped_moving_image']
warped_moving_roi = output_dict['warped_moving_roi']
warped_moving_centroids = output_dict['warped_moving_centroids']

# %%
output_dict.keys()
# Out:
# dict_keys(['warped_moving_image', 'warped_moving_roi', 'warped_moving_centroids'])

# %%
warped_moving_image.shape, warped_moving_roi.shape, warped_moving_centroids.shape
# Out:
# ((1080, 1080, 2), (1080, 1080, 2), (200, 3))

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
if len(warped_moving_image.shape) == 2:
    axes[0].imshow(warped_moving_image);
else:
    axes[0].imshow(warped_moving_image.max(2));
axes[0].set_title("warped moving image", fontsize=20);
axes[1].imshow(warped_moving_roi.max(2));
axes[1].set_title("warped moving roi", fontsize=20);

axes[2].imshow(warped_moving_roi.max(2));
axes[2].set_title("warped moving roi", fontsize=20);

xs = [x for (x, _, _) in warped_moving_centroids]
ys = [y for (_, y, _) in warped_moving_centroids]


axes[2].scatter(ys, xs, s=5, c='r');
axes[2].set_title("warped moving centroids", fontsize=20);
# axes[2].set_xlim(0, 120);
# axes[2].set_ylim(0, 284);
axes[2].invert_yaxis()

# %%
import h5py
test_path = "/home/brian/data4/brian/PBnJ/test_data/circles_padded"

with h5py.File(os.path.join(test_path, "moving_images.h5"), 'r') as f:
    mov_img = f[registration_prob][:]

with h5py.File(os.path.join(test_path, "fixed_images.h5"), 'r') as f:
    fix_img = f[registration_prob][:]


with h5py.File(os.path.join(test_path, "fixed_labels.h5"), 'r') as f:
    fix_labs = f[registration_prob][:]

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
if len(warped_moving_image.shape) == 2:
    axes[0].imshow(mov_img)
else:
    axes[0].imshow(mov_img.max(2))
axes[0].set_title("moving image", fontsize=20)
if len(warped_moving_image.shape) == 2:
    axes[1].imshow(warped_moving_image)
else:
    axes[1].imshow(warped_moving_image[...,1])
axes[1].set_title("warped moving image", fontsize=20)

if len(warped_moving_image.shape) == 2:
    axes[2].imshow(fix_img)
else:
    axes[2].imshow(fix_img.max(2))

xs = [x for (x, _, _) in warped_moving_centroids]
ys = [y for (_, y, _) in warped_moving_centroids]


# axes[1].scatter(ys, xs, s=5, c='r')


xs = [x for (x, _, _) in fix_labs if x >= 0]
ys = [y for (_, y, _) in fix_labs if y >= 0]

axes[2].set_title("fixed image", fontsize=20)
# axes[2].scatter(xs, ys, s=5, c='g')
# axes[2].set_xlim(0, 120)
# axes[2].set_ylim(0, 284)
axes[0].invert_yaxis()
axes[1].invert_yaxis()
axes[2].invert_yaxis()
